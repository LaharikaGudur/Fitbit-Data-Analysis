# %% [markdown]
# **Fitbit** data analysis for sleep days:
#
# *   Provides valuable insights into users' sleep quality, duration, and patterns. By monitoring sleep metrics and identifying areas for improvement, individuals can optimize their sleep habits and promote better overall health and well-being.

# %% [markdown]
# Objective:
#
# *   Sleep duration measures the total amount of time users spend asleep during sleep days. It helps identify regularities or irregularities in users' sleep routines and habits. Analyzing sleep patterns can uncover trends, such as changes in bedtime or wake-up time, that may impact overall sleep quality and daytime functioning.

# %% [markdown]
# 1. Importing all needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

# %% [markdown]
# 2.Loading Dataset for further process

# %%
sleep_day = pd.read_csv('/content/sleepDay_merged.csv')

# %% [markdown]
# 3. Analysis of dataset

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %% [markdown]
# 4. Checking Data type of dataset

# %%
sleep_day.dtypes
# Out:
# Id                     int64
# SleepDay              object
# TotalSleepRecords      int64
# TotalMinutesAsleep     int64
# TotalTimeInBed         int64
# WeekDay                int64
# dtype: object

# %% [markdown]
# 5. Changing the datain proper formate

# %%
sleep_day["SleepDay"] = pd.to_datetime(sleep_day["SleepDay"])

#Checking for changes in proper formate
print("Sleep Day data type is ",sleep_day["SleepDay"].dtypes)
# Out:
# Sleep Day data type is  datetime64[ns]

# %% [markdown]
# 6. Checking unique users

# %%
print("Sleep day Datataset:",sleep_day.Id.nunique(),"unique users")
# Out:
# Sleep day Datataset: 24 unique users

# %% [markdown]
# 7.Checking shape of Dataset

# %%
print("Shape of Hourly_calories:",sleep_day.shape)

# %% [markdown]
# 8. Checking null values

# %% [markdown]
# 8. Checking for null values in dataset

# %%
print("Hourly_calories Dataset has missing values:",sleep_day.isna().sum())
# Out:
# Hourly_calories Dataset has missing values: Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %% [markdown]
# 9. Analysing the data tpye of dataset

# %%
sleep_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    datetime64[ns]
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
#  5   WeekDay             413 non-null    int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 19.5 KB

# %% [markdown]
# 10. Visualising the  cleaned & sorted dataset

# %% [markdown]
# Assuming the dataset has columns 'SleepDays' and 'TotalSleepRecord'
# Replace the column names accordingly if they are different in your dataset

# %%
# Plotting heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.pivot_table(index='SleepDay', columns='TotalSleepRecords', aggfunc='size'), cmap="YlGnBu", annot=True)
plt.title('Sleep Days vs Total Sleep Record')
plt.xlabel('Total Sleep Record')
plt.ylabel('Sleep Days')
plt.show()

# %% [markdown]
# KeyFindings:
#
# *  Sleep record analysis examines users sleep-wake cycles and patterns over time. Analyzing sleep patterns can uncover trends, such as changes in bedtime or wake-up time, that may impact overall sleep quality and daytime functioning.

# %%
from matplotlib import pyplot as plt
_df_3.plot(kind='scatter', x='TotalSleepRecords', y='TotalMinutesAsleep', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Key Findings:
#
# *    It provides users to assess the quality of their sleep on sleep days. Analyzing sleep scores helps users track improvements or declines in sleep quality over time and make adjustments to their sleep routines accordingly.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['SleepDay']
  ys = series['TotalSleepRecords']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_5.sort_values('SleepDay', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('SleepDay')
_ = plt.ylabel('TotalSleepRecords')

# %% [markdown]
# Key Findings:
#
# *    Analyzing Totalsleep data helps to find sleep and wake up time, that may impact overall sleep quality and daytime functioning & identify factors that may affect sleep quality, such as stress, environmental factors, or sleep disorders.
